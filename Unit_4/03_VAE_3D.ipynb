# %% [markdown]
# # Variational Autoencoder with 3D Latent Space
#
# Same VAE recipe as `02_VAE_2D.ipynb` but with `z_dim = 3`. Compares against the
# plain AE from `01_FC_Autoencoder_3D.ipynb`.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401
from torchvision import datasets, transforms

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
bs = 256
train_dataset = datasets.MNIST(root="./data/", train=True, download=True, transform=transforms.ToTensor())
test_dataset = datasets.MNIST(root="./data/", train=False, download=True, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=bs, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=bs, shuffle=False)
print(f"Train: {len(train_dataset)}, Test: {len(test_dataset)}")
# Out:
# Train: 60000, Test: 10000

# %% [markdown]
# ## 1. Model

# %%
class VAE(nn.Module):
    def __init__(self, x_dim, h_dim1, h_dim2, z_dim):
        super().__init__()
        # encoder part
        self.fc1 = nn.Linear(x_dim, h_dim1)
        self.fc2 = nn.Linear(h_dim1, h_dim2)
        self.fc31 = nn.Linear(h_dim2, z_dim)
        self.fc32 = nn.Linear(h_dim2, z_dim)
        # decoder part
        self.fc4 = nn.Linear(z_dim, h_dim2)
        self.fc5 = nn.Linear(h_dim2, h_dim1)
        self.fc6 = nn.Linear(h_dim1, x_dim)

    def encoder(self, x):
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        return self.fc31(h), self.fc32(h)  # mu, log_var

    def sampling(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)

    def decoder(self, z):
        h = F.relu(self.fc4(z))
        h = F.relu(self.fc5(h))
        return torch.sigmoid(self.fc6(h))

    def forward(self, x):
        mu, log_var = self.encoder(x.view(-1, 784))
        z = self.sampling(mu, log_var)
        return self.decoder(z), mu, log_var


vae = VAE(x_dim=784, h_dim1=512, h_dim2=256, z_dim=10).to(device)
print(vae)
# Out:
# VAE(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc31): Linear(in_features=256, out_features=10, bias=True)
#   (fc32): Linear(in_features=256, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=256, bias=True)
#   (fc5): Linear(in_features=256, out_features=512, bias=True)
#   (fc6): Linear(in_features=512, out_features=784, bias=True)
# )

# %% [markdown]
# ## 2. Loss and Optimizer

# %%
optimizer = optim.Adam(vae.parameters())

def loss_function(recon_x, x, mu, log_var):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction="sum")
    KLD = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    return BCE + KLD

# %% [markdown]
# ## 3. Training

# %%
def train(epoch):
    vae.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()

        recon_batch, mu, log_var = vae(data)
        loss = loss_function(recon_batch, data, mu, log_var)

        loss.backward()
        train_loss += loss.item()
        optimizer.step()

        if batch_idx % 100 == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item() / len(data)))
    print("====> Epoch: {} Average loss: {:.4f}".format(epoch, train_loss / len(train_loader.dataset)))


def test():
    vae.eval()
    test_loss = 0
    with torch.no_grad():
        for data, _ in test_loader:
            data = data.to(device)
            recon, mu, log_var = vae(data)
            test_loss += loss_function(recon, data, mu, log_var).item()
    test_loss /= len(test_loader.dataset)
    print("====> Test set loss: {:.4f}".format(test_loss))

# %%
for epoch in range(1, 31):
    train(epoch)
    test()

torch.save(vae.state_dict(), "fc_vae_3d.pth")
print("Saved fc_vae_3d.pth")
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 545.003845
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 194.129471
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 161.959702
# ====> Epoch: 1 Average loss: 196.0106
# ====> Test set loss: 155.3269
# Train Epoch: 2 [0/60000 (0%)]	Loss: 157.442276
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 137.189056
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 129.412216
# ====> Epoch: 2 Average loss: 139.1949
# ====> Test set loss: 129.0220
# Train Epoch: 3 [0/60000 (0%)]	Loss: 131.787781
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 126.384438
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 122.084206
# ====> Epoch: 3 Average loss: 124.4585
# ====> Test set loss: 119.6698
# Train Epoch: 4 [0/60000 (0%)]	Loss: 121.185547
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 120.916077
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 113.771988
# ====> Epoch: 4 Average loss: 117.9203
# ====> Test set loss: 115.1746
# Train Epoch: 5 [0/60000 (0%)]	Loss: 115.167946
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 115.173874
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 112.112640
# ====> Epoch: 5 Average loss: 114.2793
# ====> Test set loss: 113.1111
# Train Epoch: 6 [0/60000 (0%)]	Loss: 117.989357
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 109.290131
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 108.260666
# ====> Epoch: 6 Average loss: 111.7455
# ====> Test set loss: 110.6210
# Train Epoch: 7 [0/60000 (0%)]	Loss: 112.146255
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 109.930511
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 110.015343
# ====> Epoch: 7 Average loss: 110.1038
# ====> Test set loss: 109.1231
# Train Epoch: 8 [0/60000 (0%)]	Loss: 110.330429
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 108.686676
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 110.513245
# ====> Epoch: 8 Average loss: 108.7962
# ====> Test set loss: 108.7650
# Train Epoch: 9 [0/60000 (0%)]	Loss: 108.825356
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 105.923447
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 111.240234
# ====> Epoch: 9 Average loss: 107.8827
# ====> Test set loss: 107.6960
# Train Epoch: 10 [0/60000 (0%)]	Loss: 109.198578
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 104.417465
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 106.107056
# ====> Epoch: 10 Average loss: 107.0035
# ====> Test set loss: 106.6574
# Train Epoch: 11 [0/60000 (0%)]	Loss: 103.026825
# Train Epoch: 11 [25600/60000 (43%)]	Loss: 108.330704
# Train Epoch: 11 [51200/60000 (85%)]	Loss: 105.182770
# ====> Epoch: 11 Average loss: 106.3194
# ====> Test set loss: 105.8321
# Train Epoch: 12 [0/60000 (0%)]	Loss: 102.284393
# Train Epoch: 12 [25600/60000 (43%)]	Loss: 105.413925
# Train Epoch: 12 [51200/60000 (85%)]	Loss: 105.689522
# ====> Epoch: 12 Average loss: 105.6490
# ====> Test set loss: 105.2436
# Train Epoch: 13 [0/60000 (0%)]	Loss: 104.896645
# Train Epoch: 13 [25600/60000 (43%)]	Loss: 105.438385
# Train Epoch: 13 [51200/60000 (85%)]	Loss: 104.794556
# ====> Epoch: 13 Average loss: 105.1404
# ====> Test set loss: 105.2340
# Train Epoch: 14 [0/60000 (0%)]	Loss: 106.771790
# Train Epoch: 14 [25600/60000 (43%)]	Loss: 103.493034
# Train Epoch: 14 [51200/60000 (85%)]	Loss: 107.192810
# ====> Epoch: 14 Average loss: 104.6171
# ====> Test set loss: 104.5933
# Train Epoch: 15 [0/60000 (0%)]	Loss: 104.928108
# Train Epoch: 15 [25600/60000 (43%)]	Loss: 103.968536
# Train Epoch: 15 [51200/60000 (85%)]	Loss: 105.043640
# ====> Epoch: 15 Average loss: 104.1902
# ====> Test set loss: 104.6935
# Train Epoch: 16 [0/60000 (0%)]	Loss: 102.953278
# Train Epoch: 16 [25600/60000 (43%)]	Loss: 104.153412
# Train Epoch: 16 [51200/60000 (85%)]	Loss: 101.583832
# ====> Epoch: 16 Average loss: 103.7978
# ====> Test set loss: 104.2413
# Train Epoch: 17 [0/60000 (0%)]	Loss: 101.716202
# Train Epoch: 17 [25600/60000 (43%)]	Loss: 100.952835
# Train Epoch: 17 [51200/60000 (85%)]	Loss: 101.886925
# ====> Epoch: 17 Average loss: 103.4144
# ====> Test set loss: 103.6098
# Train Epoch: 18 [0/60000 (0%)]	Loss: 101.825302
# Train Epoch: 18 [25600/60000 (43%)]	Loss: 105.535271
# Train Epoch: 18 [51200/60000 (85%)]	Loss: 104.130470
# ====> Epoch: 18 Average loss: 103.0927
# ====> Test set loss: 103.3976
# Train Epoch: 19 [0/60000 (0%)]	Loss: 100.672684
# Train Epoch: 19 [25600/60000 (43%)]	Loss: 101.894333
# Train Epoch: 19 [51200/60000 (85%)]	Loss: 99.783409
# ====> Epoch: 19 Average loss: 102.7687
# ====> Test set loss: 103.2928
# Train Epoch: 20 [0/60000 (0%)]	Loss: 104.095795
# Train Epoch: 20 [25600/60000 (43%)]	Loss: 101.084763
# Train Epoch: 20 [51200/60000 (85%)]	Loss: 102.916779
# ====> Epoch: 20 Average loss: 102.4885
# ====> Test set loss: 103.0402
# Train Epoch: 21 [0/60000 (0%)]	Loss: 101.785522
# Train Epoch: 21 [25600/60000 (43%)]	Loss: 102.815445
# Train Epoch: 21 [51200/60000 (85%)]	Loss: 101.638229
# ====> Epoch: 21 Average loss: 102.1698
# ====> Test set loss: 102.9714
# Train Epoch: 22 [0/60000 (0%)]	Loss: 104.174850
# Train Epoch: 22 [25600/60000 (43%)]	Loss: 102.305801
# Train Epoch: 22 [51200/60000 (85%)]	Loss: 101.938225
# ====> Epoch: 22 Average loss: 101.9389
# ====> Test set loss: 103.0287
# Train Epoch: 23 [0/60000 (0%)]	Loss: 104.285706
# Train Epoch: 23 [25600/60000 (43%)]	Loss: 103.349655
# Train Epoch: 23 [51200/60000 (85%)]	Loss: 99.108154
# ====> Epoch: 23 Average loss: 101.6798
# ====> Test set loss: 102.4182
# Train Epoch: 24 [0/60000 (0%)]	Loss: 101.284637
# Train Epoch: 24 [25600/60000 (43%)]	Loss: 103.081177
# Train Epoch: 24 [51200/60000 (85%)]	Loss: 100.850182
# ====> Epoch: 24 Average loss: 101.4634
# ====> Test set loss: 102.2795
# Train Epoch: 25 [0/60000 (0%)]	Loss: 102.189514
# Train Epoch: 25 [25600/60000 (43%)]	Loss: 101.817902
# Train Epoch: 25 [51200/60000 (85%)]	Loss: 99.394653
# ====> Epoch: 25 Average loss: 101.2588
# ====> Test set loss: 102.3322
# Train Epoch: 26 [0/60000 (0%)]	Loss: 101.526009
# Train Epoch: 26 [25600/60000 (43%)]	Loss: 101.705032
# Train Epoch: 26 [51200/60000 (85%)]	Loss: 101.635384
# ====> Epoch: 26 Average loss: 101.0453
# ====> Test set loss: 102.2672
# Train Epoch: 27 [0/60000 (0%)]	Loss: 100.787521
# Train Epoch: 27 [25600/60000 (43%)]	Loss: 103.433075
# Train Epoch: 27 [51200/60000 (85%)]	Loss: 103.010223
# ====> Epoch: 27 Average loss: 100.8774
# ====> Test set loss: 101.8586
# Train Epoch: 28 [0/60000 (0%)]	Loss: 101.385559
# Train Epoch: 28 [25600/60000 (43%)]	Loss: 101.065201
# Train Epoch: 28 [51200/60000 (85%)]	Loss: 102.128578
# ====> Epoch: 28 Average loss: 100.6957
# ====> Test set loss: 102.0329
# Train Epoch: 29 [0/60000 (0%)]	Loss: 100.545975
# Train Epoch: 29 [25600/60000 (43%)]	Loss: 102.979813
# Train Epoch: 29 [51200/60000 (85%)]	Loss: 102.672989
# ====> Epoch: 29 Average loss: 100.5134
# ====> Test set loss: 101.7699
# Train Epoch: 30 [0/60000 (0%)]	Loss: 101.933968
# Train Epoch: 30 [25600/60000 (43%)]	Loss: 97.556610
# Train Epoch: 30 [51200/60000 (85%)]	Loss: 103.429932
# ====> Epoch: 30 Average loss: 100.4008
# ====> Test set loss: 101.7517
# Saved fc_vae_3d.pth

# %% [markdown]
# ## 4. Reconstruction Quality

# %%
vae.eval()
data, _ = next(iter(test_loader))
data = data[:10].to(device)
with torch.no_grad():
    recon, _, _ = vae(data)
recon = recon.view(-1, 1, 28, 28)

fig, axes = plt.subplots(2, 10, figsize=(15, 4))
for i in range(10):
    axes[0, i].imshow(data[i].cpu().squeeze(), cmap="gray"); axes[0, i].axis("off")
    axes[1, i].imshow(recon[i].cpu().squeeze(), cmap="gray"); axes[1, i].axis("off")

plt.suptitle("VAE reconstruction with 3-D bottleneck", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. The 3D Latent Space
#
# Encode the entire test set and plot the encoder means $\mu$ in 3D.

# %%
all_mu, all_labels = [], []
with torch.no_grad():
    for data, labels in test_loader:
        mu, _ = vae.encoder(data.to(device).view(-1, 784))
        all_mu.append(mu.cpu()); all_labels.append(labels)
all_mu = torch.cat(all_mu).numpy()
all_labels = torch.cat(all_labels).numpy()

for i in range(3):
    print(f"mu_{i+1}: range [{all_mu[:, i].min():.2f}, {all_mu[:, i].max():.2f}], "
          f"mean={all_mu[:, i].mean():.2f}, std={all_mu[:, i].std():.2f}")
# Out:
# mu_1: range [-3.87, 3.52], mean=0.06, std=0.99
# mu_2: range [-3.24, 3.29], mean=0.11, std=0.97
# mu_3: range [-3.41, 3.58], mean=-0.02, std=0.95

# %% [markdown]
# ## 6. Side-by-Side: AE vs VAE Latent Space
#
# Load the AE latents from `01_FC_Autoencoder_3D.ipynb` and plot both clouds with
# the same axis limits so the difference in scale and shape is obvious.

# %%
ae_data = np.load("latents_ae_3d.npz")
ae_z = ae_data["z"]
ae_labels = ae_data["labels"]

all_pts = np.vstack([ae_z, all_mu])
lo, hi = all_pts.min(), all_pts.max()

fig = plt.figure(figsize=(15, 7))
for k, (pts, labels, title) in enumerate(
    [(ae_z, ae_labels, "AE"), (all_mu, all_labels, "VAE")]
):
    ax = fig.add_subplot(1, 2, k + 1, projection="3d")
    sc = ax.scatter(pts[:, 0], pts[:, 1], pts[:, 2],
                    c=labels, cmap="tab10", s=3, alpha=0.6)
    ax.set_xlim(lo, hi); ax.set_ylim(lo, hi); ax.set_zlim(lo, hi)
    ax.set_xlabel("$z_1$"); ax.set_ylabel("$z_2$"); ax.set_zlabel("$z_3$")
    ax.set_title(f"{title} latent space  (range x: [{pts[:,0].min():.1f}, {pts[:,0].max():.1f}])")
fig.suptitle("AE (no constraint) vs VAE (KL pulls toward unit Gaussian) — same axes", fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Sampling: $z \sim \mathcal{N}(0, I)$
#
# Run the same Gaussian samples through both decoders.

# %%
# Reload the AE for the side-by-side decoder comparison
class FCAutoencoder(nn.Module):
    def __init__(self, latent_dim=10):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28 * 28, 256), nn.ReLU(),
            nn.Linear(256, 64), nn.ReLU(),
            nn.Linear(64, latent_dim),
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64), nn.ReLU(),
            nn.Linear(64, 256), nn.ReLU(),
            nn.Linear(256, 28 * 28), nn.Sigmoid(),
        )

    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z).view(-1, 1, 28, 28), z

ae = FCAutoencoder(10).to(device)
ae.load_state_dict(torch.load("fc_autoencoder_3d.pth", map_location=device))
ae.eval()

torch.manual_seed(0)
N = 16
z = torch.randn(N, 10, device=device)
with torch.no_grad():
    ae_samples = ae.decoder(z).view(-1, 28, 28).cpu()
    vae_samples = vae.decoder(z).view(-1, 28, 28).cpu()

fig, axes = plt.subplots(2, N, figsize=(1.4 * N, 3))
for j in range(N):
    axes[0, j].imshow(ae_samples[j], cmap="gray", vmin=0, vmax=1); axes[0, j].axis("off")
    axes[1, j].imshow(vae_samples[j], cmap="gray", vmin=0, vmax=1); axes[1, j].axis("off")

fig.suptitle("Same $z \\sim \\mathcal{N}(0, I)$ through both decoders", fontsize=12)
plt.tight_layout()
plt.show()
